# %%
#!pip install lxml

# %%
import yfinance
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import yfinance as yf

aapl = yf.Ticker("AAPL")

# %%
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
# ...

# %%
start_date = "2010-01-01"
end_date = "2020-06-29"
hist = aapl.history(period="max")

# %%
aapl.actions.sort_values("Dividends")
#result.sort(key = lambda x : -x['training_forward_return'])
# Out:
#             Dividends  Stock Splits
# Date
# 2014-06-09    0.00000           7.0
# 2013-02-07    0.37857           0.0
# 2012-08-09    0.37857           0.0
# 2012-11-07    0.37857           0.0
# 2013-05-09    0.43571           0.0
# 2013-08-08    0.43571           0.0
# 2013-11-06    0.43571           0.0
# 2014-02-06    0.43571           0.0
# 2014-05-08    0.47000           0.0
# 2014-08-07    0.47000           0.0
# 2014-11-06    0.47000           0.0
# 2015-02-05    0.47000           0.0
# 2015-05-07    0.52000           0.0
# 2015-08-06    0.52000           0.0
# 2015-11-05    0.52000           0.0
# 2016-02-04    0.52000           0.0
# 2017-02-09    0.57000           0.0
# 2016-11-03    0.57000           0.0
# 2016-05-05    0.57000           0.0
# 2016-08-04    0.57000           0.0
# 2017-05-11    0.63000           0.0
# 2017-08-10    0.63000           0.0
# 2017-11-10    0.63000           0.0
# 2018-02-09    0.63000           0.0
# 2018-05-11    0.73000           0.0
# ...

# %%
aapl.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.quarterly_financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  62.12%       % of Shares Held by Institutions
# 2  62.16%        % of Float Held by Institutions
# 3    4296  Number of Institutions Holding Shares

# %%
aapl.balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.quarterly_balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.cashflow
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.quarterly_cashflow
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.quarterly_earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.sustainability
# Out:
#                                      Value
# 2020-3
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                             13
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                         0
# peerCount                               57
# governanceScore                      10.26
# environmentPercentile                    0
# animalTesting                        False
# tobacco                              False
# totalEsg                             23.82
# highestControversy                       3
# esgPerformance                    AVG_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
aapl.recommendations
# Out:
#                                   Firm        To Grade From Grade Action
# Date
# 2012-02-09 08:17:00  Canaccord Genuity             Buy              main
# 2012-03-08 07:33:00     FBN Securities      Outperform              main
# 2012-03-13 06:08:00          Jefferies             Buy              main
# 2012-03-14 06:13:00     Morgan Stanley      Overweight              main
# 2012-03-14 08:21:00  Canaccord Genuity             Buy              main
# ...                                ...             ...        ...    ...
# 2020-06-23 11:57:21              Baird      Outperform              main
# 2020-06-23 15:44:48          Bernstein  Market Perform              main
# 2020-06-23 15:49:39      Deutsche Bank             Buy              main
# 2020-06-23 15:51:49                UBS             Buy              main
# 2020-06-25 09:00:31            Wedbush      Outperform              main
#
# [713 rows x 4 columns]

# %%
aapl.calendar
# Out:
#                                     0                    1
# Earnings Date     2020-07-28 00:00:00  2020-08-03 00:00:00
# Earnings Average                    2                    2
# Earnings Low                     1.55                 1.55
# Earnings High                    2.47                 2.47
# Revenue Average           51510300000          51510300000
# Revenue Low               42799000000          42799000000
# Revenue High              55838000000          55838000000

# %%
aapl.isin
# Out:
# 'US0378331005'

# %%
aapl.options
# Out:
# ('2020-07-02',
#  '2020-07-10',
#  '2020-07-17',
#  '2020-07-24',
#  '2020-07-31',
#  '2020-08-07',
#  '2020-08-21',
#  '2020-09-18',
#  '2020-10-16',
#  '2020-11-20',
#  '2020-12-18',
#  '2021-01-15',
#  '2021-06-18',
#  '2021-09-17',
#  '2022-01-21',
#  '2022-06-17',
#  '2022-09-16')

# %%
opt = aapl.option_chain('YYYY-MM-DD')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-f41b4cb6ab6d> in <module>
# ----> 1 opt = aapl.option_chain('YYYY-MM-DD')
#
# ~/anaconda3/envs/sm/lib/python3.6/site-packages/yfinance/ticker.py in option_chain(self, date, proxy, tz)
#      95                     "Expiration `%s` cannot be found. "
#      96                     "Available expiration are: [%s]" % (
# ---> 97                         date, ', '.join(self._expirations)))
#      98             date = self._expirations[date]
#      99             options = self._download_options(date, proxy=proxy)
#
# ValueError: Expiration `YYYY-MM-DD` cannot be found. Available expiration are: [2020-07-02, 2020-07-10, 2020-07-17, 2020-07-24, 2020-07-31, 2020-08-07, 2020-08-21, 2020-09-18, 2020-10-16, 2020-11-20, 2020-12-18, 2021-01-15, 2021-06-18, 2021-09-17, 2022-01-21, 2022-06-17, 2022-09-16]

# %%
n_forward = 2
tickers = yf.Tickers('AAPL NVDA')
data = tickers.history(interval="1d",start=start_date,end=end_date)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data.head()
# Out:
#                 Close            Dividends            High             \
#                  AAPL       NVDA      AAPL NVDA       AAPL       NVDA
# Date
# 2010-01-04  26.466835  17.010056       0.0  0.0  26.527434  17.129651
# 2010-01-05  26.512596  17.258446       0.0  0.0  26.662238  17.442437
# 2010-01-06  26.090879  17.368835       0.0  0.0  26.617719  17.405635
# 2010-01-07  26.042646  17.028448       0.0  0.0  26.218260  17.350434
# 2010-01-08  26.215786  17.065248       0.0  0.0  26.218259  17.184844
#
#                   Low                  Open            Stock Splits       \
#                  AAPL       NVDA       AAPL       NVDA         AAPL NVDA
# Date
# 2010-01-04  26.265252  16.660472  26.395106  17.028455          0.0    0
# 2010-01-05  26.372848  16.945659  26.539804  16.945659          0.0    0
# 2010-01-06  26.063673  17.083648  26.512597  17.249241          0.0    0
# 2010-01-07  25.853430  16.899654  26.187342  17.276838          0.0    0
# ...

# %%
data['Forward Close'] = data['Close'].shift(-n_forward)

# The revenue from Forward Close which include Close price 2days after(future) to Current Close price.
data['Forward Return'] = (data['Forward Close'] - data['Close'])/data['Close']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/sm/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Forward Close'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
